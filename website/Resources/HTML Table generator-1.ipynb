# %%
import pandas as pd

# Read the csv file in
df = pd.read_csv('../Resources/city_data_df.csv')

# Save to file
df.to_html('data.html', index=False)

# Assign to string
table = df.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>souillac</td>
#       <td>-20.5167</td>
#       <td>57.5167</td>
#       <td>73.29</td>
#       <td>69</td>
#       <td>9</td>
#       <td>16.51</td>
#       <td>MU</td>
#       <td>1658563265</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>ribeira grande</td>
#       <td>38.5167</td>
#       <td>-28.7000</td>
#       <td>72.00</td>
#       <td>83</td>
#       <td>40</td>
#       <td>5.75</td>
#       <td>PT</td>
#       <td>1658563166</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
from pretty_html_table import build_table

df = pd.read_csv('../Resources/city_data_df.csv')
html_table_blue_light = build_table(df, 'blue_light', index= False)

# Save to html file
with open('pretty_table.html', 'w') as f:
    f.write(html_table_blue_light)

# Compare to the pandas .to_html method:
# with open('pandas_table.html', 'w') as f:
#     f.write(df.to_html())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_63264\3215551137.py in <module>
#       4 html_table_blue_light = build_table(df, 'blue_light', index= False)
#       5
# ----> 6 html_table_blue_light=html_table_blue_light.set_index('City')
#       7
#       8 # Save to html file
#
# AttributeError: 'str' object has no attribute 'set_index'
